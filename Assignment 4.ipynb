# %%
#importing all the required libraries
import pandas as pd
import selenium
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from time import sleep
import warnings
warnings.filterwarnings('ignore')
import time
import string

# %%
#intialising driver
driver=webdriver.Chrome(r"C:\Users\Home\Downloads\chromedriver_win32 (2)\chromedriver.exe")

# %% [markdown]
# Q.no 1. Scrape the details of most viewed videos on YouTube from Wikipedia:
#
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/ You need to find following details:
#
# A) Rank B) Name C) Artist D) Upload date E) Views

# %%
# creating empty lists for scraping data
Rank=[]
Name=[]
Artist=[]
Upload_Date=[]
Views=[]

# %%
#getting the required URL
driver.get("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/")

# %%
time.sleep(3)

# %%
insert=driver.find_element_by_xpath("//td[@class='mbox-text']/span[@class='plainlinks']/a[@class='external text']/i").click()

# %%
time.sleep(3)

# %%
insert1=driver.find_element_by_xpath("//li[1]/div[@class='mw-search-result-heading']/a").click()

# %%
#scraping the rank
rank=driver.find_elements_by_xpath("//tbody/tr/td[1]")
for i in rank[:30]:
    Rank.append(i.text)#appending rank
    
time.sleep(5)

#scraping the name
name=driver.find_elements_by_xpath("//tbody/tr/td[2]")
for i in name[:30]:
    Name.append(i.text)#appending name
    
time.sleep(5)

#scraping the artist
artist=driver.find_elements_by_xpath("//tbody/tr/td[3]")
for i in artist[:30]:
    Artist.append(i.text)#appending artist name
    
#time.sleep(5)

#scraping upload date
upload=driver.find_elements_by_xpath("//tbody/tr/td[5]")
for i in upload[:30]:
    Upload_Date.append(i.text)#appending upload date
    
time.sleep(5)

#scraping views
views=driver.find_elements_by_xpath("//tbody/tr/td[4]")
for i in views[:30]:
    Views.append(i.text)#appending total no of views

# %%
#checking the length of each list
print(len(Rank))
print(len(Name))
print(len(Artist))
print(len(Upload_Date))
print(len(Views))
# Out:
# 30
# 30
# 30
# 30
# 30

# %%
#creating a dataframe
df=pd.DataFrame({'Rank':Rank,'Name':Name,'Artist':Artist,'Upload Date':Upload_Date,'Views':Views})

df
# Out:
#    Rank                                               Name  \
# 0        This article has multiple issues. Please help ...
# 1        This article needs additional citations for ve...
# 2            This article needs to be updated. (July 2021)
# 3        This section possibly contains original resear...
# 4    1.                             "Baby Shark Dance"[23]
# 5    2.                                    "Despacito"[25]
# 6    3.                         "Johny Johny Yes Papa"[26]
# 7    4.                                 "Shape of You"[27]
# 8    5.                                "See You Again"[28]
# 9    6.                                    "Bath Song"[31]
# 10   7.    "Learning Colors – Colorful Eggs on a Farm"[32]
# 11   8.     "Masha and the Bear – Recipe for Disaster"[33]
# 12   9.                                  "Uptown Funk"[34]
# 13  10.                  "Phonics Song with Two Words"[35]
# 14  11.                                "Gangnam Style"[36]
# ...

# %% [markdown]
# Q2. Scrape the details team India’s international fixtures from bcci.tv.
#
# Url = https://www.bcci.tv/.
#
# You need to find following details:
#
# A) Match title (I.e. 1
#
# st ODI)
#
# B) Series
#
# C) Place
#
# D) Date
#
# E) Time

# %%
#intialising driver
driver=webdriver.Chrome(r"C:\Users\Home\Downloads\chromedriver_win32 (2)\chromedriver.exe")

# %%
# creating empty lists for scraping data
Match_title=[]
Series=[]
Place=[]
Date=[]
Month=[]
#Time=[]

# %%
#getting the required Url
driver.get("https://www.bcci.tv/")

# %%
insert = driver.find_element_by_xpath("//li[1]//div[@class='navigation__drop-down drop-down drop-down--reveal-on-hover']")
insert.click()

# %%
insert1 = driver.find_element_by_xpath("//li[1]/div[@class='navigation__drop-down drop-down drop-down--reveal-on-hover']/div[1]/ul[1]/li[1]/a[@href='/international/fixtures']")
insert1.click()

# %%
#scraping match title
match = driver.find_elements_by_xpath("//p[@class='fixture__additional-info']/strong")
for i in match:
    Match_title.append(i.text)#appenind match title
    

#scraping series
series = driver.find_elements_by_xpath("//span[@class='u-unskewed-text fixture__tournament-label u-truncated']")
for i in series:
    Series.append(i.text)#appending series
    

#scraping place
place = driver.find_elements_by_xpath("//p[@class='fixture__additional-info']/span")
for i in place:
    Place.append(i.text)#appending place
    

#scraping date
date = driver.find_elements_by_xpath("//div[@class='fixture__full-date']/span")
for i in date:
    Date.append(i.text)#appending date
    

#scraping month
month = driver.find_elements_by_xpath("//div[@class='fixture__date-details']/span[1]")
for i in month:
    Month.append(i.text)#appending month
    

#scraping time
#time = driver.find_elements_by_xpath("//div[@class='fixture__date-details']/span[2]")
#for i in time:
 #   Time.append(i.text)#appending time

# %%
#checking the length of each list
print(len(Match_title))
print(len(Series))
print(len(Place))
print(len(Date))
print(len(Month))
#print(len(Time))
# Out:
# 10
# 10
# 10
# 10
# 10

# %%
#creating a dataframe
df1=pd.DataFrame({'Match Title':Match_title,'Series':Series,'Place':Place,'Date':Date,'Month':Month})

df1
# Out:
#   Match Title                        Series  \
# 0    Match 42  2021 ICC MEN'S T20 WORLD CUP
# 1    1st T20I      INDIA V NEW ZEALAND 2021
# 2    2nd T20I      INDIA V NEW ZEALAND 2021
# 3    3rd T20I      INDIA V NEW ZEALAND 2021
# 4    1st Test      INDIA V NEW ZEALAND 2021
# 5    2nd Test      INDIA V NEW ZEALAND 2021
# 6     1st ODI      INDIA V WEST INDIES 2022
# 7     2nd ODI      INDIA V WEST INDIES 2022
# 8     3rd ODI      INDIA V WEST INDIES 2022
# 9    1st T20I      INDIA V WEST INDIES 2022
#
#                                         Place Date     Month
# 0          Dubai International Stadium, Dubai   08  NOVEMBER
# 1              Sawai Mansingh Stadium, Jaipur   17  NOVEMBER
# 2  JSCA International Stadium Complex, Ranchi   19  NOVEMBER
# 3                       Eden Gardens, Kolkata   21  NOVEMBER
# 4                          Green Park, Kanpur   25  NOVEMBER
# 5                    Wankhede Stadium, Mumbai   03  DECEMBER
# ...

# %% [markdown]
# Q3.Scrape the details of selenium exception from guru99.com.
#
# Url = https://www.guru99.com/
#
# You need to find following details:
#
# A) Name
#
# B) Description

# %%
#intialising driver
driver=webdriver.Chrome(r"C:\Users\Home\Downloads\chromedriver_win32 (2)\chromedriver.exe")

# %%
#getting the required Url
driver.get("https://www.guru99.com/")

# %%
time.sleep(5)

# %%
selenium=driver.find_element_by_xpath('//div[@class="featured-box cloumnsize1"]/ul/li[3]/a')

# %%
selenium.click()

# %%
tutorial=driver.find_element_by_xpath('//div[@class="entry-content single-content"]/table[5]/tbody/tr[34]/td')

# %%
tutorial.click()

# %%
exceptions=driver.find_elements_by_xpath('//table[@class="table table-striped"]/tbody/tr/td[1]')

# %%
EXCT=[]
for i in exceptions:
    if i.text is None:
        EXCT.append("--")
    else:
        EXCT.append(i.text)

# %%
desc=driver.find_elements_by_xpath('//table[@class="table table-striped"]/tbody/tr/td[2]')

# %%
DESC=[]
for i in desc:
    if i.text is None:
        DESC.append("--")
    else:
        DESC.append(i.text)

# %%
print(len(DESC),len(EXCT))
# Out:
# 0 0

# %%
df=pd.DataFrame({'Exceptions':EXCT,'Description':DESC})
df
# Out:
# Empty DataFrame
# Columns: [Exceptions, Description]
# Index: []

# %% [markdown]
# Q4.Scrape the details of State-wise GDP of India from statisticstime.com.
#
# Url = http://statisticstimes.com/
#
# You have to find following details:
#
# A) Rank
#
# B) State
#
# C) GSDP(18-19)
#
# D) GSDP(17-18)
#
# E) Share(2017)
#
# F) GDP($ billion)

# %%
#intialising driver
driver=webdriver.Chrome(r"C:\Users\Home\Downloads\chromedriver_win32 (2)\chromedriver.exe")

# %%
# creating empty lists for scraping data
Rank=[]
State=[]
GSDP_18=[]
GSDP_17=[]
Share=[]
GDP_Billion=[]

# %%
#getting the required Url
driver.get("http://statisticstimes.com/")

# %%
time.sleep(5)

# %%
insert = driver.find_element_by_xpath("//div/div/div[2]/button")
insert.click()

# %%
time.sleep(5)

# %%
insert1=driver.find_element_by_xpath("//div[@class='navbar']/div[2]/div/a[2]")
insert1.click()

# %%
time.sleep(5)

# %%
insert2 = driver.find_element_by_xpath("//ul[@style='list-style-type:none;margin-left:20px;']/li/a")
insert2.click()

# %%
time.sleep(3)

# %%
#scraping rank
rank=driver.find_elements_by_xpath("//tr/td[@class='data1']")
for i in rank[:33]:
    Rank.append(i.text)#appending rank

time.sleep(3)

#scraping state
state=driver.find_elements_by_xpath("//tr/td[@class='name']")
for j in state[:33]:
    State.append(j.text)#appending state
    
time.sleep(3)

#scraping GSDP (18-19)
gsdp18=driver.find_elements_by_xpath("//tr/td[3][@class='data']")
for j in gsdp18[:33]:
    GSDP_18.append(j.text)#appending GSDP 18-19
    
time.sleep(3)

#scraping GSDP (17-18)
gsdp17=driver.find_elements_by_xpath("//tr/td[@class='data sorting_1']")
for j in gsdp17[:33]:
    GSDP_17.append(j.text)#Appending GSDP (17-18)
    
time.sleep(3)

#scraping share
share=driver.find_elements_by_xpath("//tr/td[5][@class='data']")
for j in share[:33]:
    Share.append(j.text)#appending share
    
time.sleep(3)

#scraping GDP in billion$
billion=driver.find_elements_by_xpath("//tr/td[6][@class='data']")
for j in billion[:33]:
    GDP_Billion.append(j.text)#appending Gdp

# %%
#checking the length of each list
print(len(Rank))
#print(len(State))
print(len(GSDP_18))
#print(len(GSDP_17))
print(len(GDP_Billion))
# Out:
# 33
# 33
# 33

# %%
#creating a dataframe
df4=pd.DataFrame({'Rank':Rank,'GSDP18-19':GSDP_18,'Share 2017':Share,'GDP $ billion':GDP_Billion})

df4
# Out:
#        Rank GSDP18-19 Share 2017 GDP $ billion
# 0   103/176     78.73      77.04        0.0234
# 1    90/177     83.37      78.56        0.0220
# 2   113/199     89.11      75.60        0.0213
# 3    98/192     95.23      74.71        0.0232
# 4   116/206    101.12      72.79        0.0236
# 5    98/193    107.25      71.18        0.0265
# 6   114/206    113.63      70.16        0.0258
# 7    98/194     21.39      68.30        0.0266
# 8   114/206     21.81      64.68        0.0266
# 9    97/194     20.99      57.36        0.0242
# 10  110/207     20.74      57.12        0.0240
# 11   94/195     20.21      49.94        0.0206
# 12  111/208     19.76      41.14        0.0159
# 13   95/195     19.48      39.59        0.0168
# 14  111/208     18.96      34.78        0.0135
# 15   96/196     17.95      33.01        0.0131
# 16  111/207     15.92      29.68        0.0119
# 17   98/194     15.86      29.27        0.0116
# 18  115/208     13.87      26.89        0.0117
# ...

# %% [markdown]
# Q5.Scrape the details of trending repositories on Github.com.
#
# Url = https://github.com/
#
# You have to find the following details:
#
# A) Repository title B) Repository description C) Contributors count D) Language used

# %%
#intialising driver
driver=webdriver.Chrome(r"C:\Users\Home\Downloads\chromedriver_win32 (2)\chromedriver.exe")

# %%
# creating empty lists for scraping data
Title=[]
Description=[]
Contributors=[]
Language=[]

# %%
#getting the required Url
driver.get('https://github.com/')

# %%
time.sleep(3)

# %%
#clicking the explore menu
insert=driver.find_element_by_xpath("//li[4]/details/summary[@class='HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block']").click()

# %%
time.sleep(3)

# %%
#clicking the trending option
insert1=driver.find_element_by_xpath("//ul[@class='list-style-none mb-3']/li[3]/a").click()

# %%
#scraping the title name
title=driver.find_elements_by_xpath("//h1[@class='h3 lh-condensed']")
for i in title:
    Title.append(i.text)#appending title

# %%
urls=[i.get_attribute("href")for i in driver.find_elements_by_xpath("//article[@class='Box-row']/h1/a")]
for url in urls[0:24]:
    time.sleep(5)

           
        
    try:   #exception handling for nosuchelementexception
        
        driver.get(url)
        description=driver.find_element_by_xpath("//div[@class='BorderGrid-row hide-sm hide-md']/div/p[@class='f4 mt-3']").text
        
        Description.append(description)#appending Description of the data set
    except NoSuchElementException :
        Description.append(" ")#appending no description if their is no description provided
        
    
        
    try:    #exception handling for nosuchelementexception
        
        driver.get(url)
        contributors=driver.find_element_by_xpath("//div[@class='BorderGrid BorderGrid--spacious']/div[4]/div/h2[@class='h4 mb-3']//span").text
        
        Contributors.append(contributors)#appending contributers count
    except NoSuchElementException :
        Contributors.append(" ")#appending no contributers count if no count is given
    
    try:       #exception handling for nosuchelementexception
        
        driver.get(url)
        language=driver.find_element_by_xpath("//ul[@class='list-style-none']/li[1]/a[1]//span[1]").text
       
        Language.append(language)#appending language used
    except NoSuchElementException :
        Language.append(" ")#apeending no language used if no language is given

# %%
#checking the length of each list
#print(len(Title))
print(len(Description))
print(len(Contributors))
print(len(Language))
# Out:
# 24
# 24
# 24

# %%
# Creating  dataframe
df5 = pd.DataFrame({ 'Repository Description' : Description  , 'Contributors Count' : Contributors , 'Language Used'  : Language}  )
df5
# Out:
#                                Repository Description Contributors Count  \
# 0                         Telegram for Android source
# 1   openpilot is an open source driver assistance ...                254
# 2   Flutter makes it easy and fast to build beauti...
# 3            A black hole for Internet advertisements
# 4                               Lean's OpenWrt source                272
# 5   A collection of simple python mini projects to...
# 6   🚀AI拟声: 5秒内克隆您的声音并生成任意语音内容 Clone a voice in 5 s...
# 7   A refreshingly simple data-driven game engine ...
# 8   A fast, zero dependency object and array compa...                  1
# 9   Ultimate Solidity, Blockchain, and Smart Contr...
# 10  🚀 Boilerplate and Starter for Next.js 12+, Tai...
# 11              Bitcoin Core integration/staging tree
# 12  Windows 11 Upgrade tool that bypasses Microsof...
# 13               All Algorithms implemented in Python
# 14  A chrome extension for automating your browser...
# ...

# %% [markdown]
# Q7.Scrape the details of Data science recruiters from naukri.com.
#
# Url = https://www.naukri.com/
#
# You have to find the following details:
#
# A) Name
#
# B) Designation
#
# C) Company
#
# D) Skills they hire for
#
# E) Location

# %%
#intialising driver
driver=webdriver.Chrome(r"C:\Users\Home\Downloads\chromedriver_win32 (2)\chromedriver.exe")

# %%
driver.get("https://www.naukri.com/")

# %%
# creating empty lists for scraping data
name  = []
designation  = []
company  = []
skills   = []
location = []

# %%
#scraping name
Name = driver.find_elements_by_xpath("//p[@class='highlightable']//span[@class='fl ellipsis']")
for i in Name:
    name.append(i.text)#appending name
    
time.sleep(3)  

#scraping designation
Designation = driver.find_elements_by_xpath("//p[@class='highlightable']//span[@class='ellipsis clr']")
for i in Designation:
    designation.append(i.text)#appending designation
    
time.sleep(3)  

#scraping company name
Company = driver.find_elements_by_xpath("//p[@class='highlightable']/a[2]")
for i in Company:
    company.append(i.text)#appending company name

time.sleep(3)  

#scraping skills required
Skills= driver.find_elements_by_xpath("//div[@class='recInfo']//div[@class='hireSec highlightable']")
for i in Skills:
    skills.append(i.text)#appending skills required

# %%
## scraping location, for scraping location we have to go in each of the location separately
urls=[i.get_attribute("href")for i in driver.find_elements_by_xpath("//div[@class='vcard']/p/a[1]")]#getting the url
for url in urls[0:50]:
    time.sleep(5)
    try:            #exception handling for nosuchelementexception
        
        driver.get(url)
        Location=driver.find_element_by_xpath("//div[@class='rFrame fl infoWrapper']/div[5]/a").text
        
        location.append(Location)#appending location in location list
    except NoSuchElementException :
        location.append(" ")#appending no location if no such location is there

# %%
#checking the length of each list
print(len(name))
print(len(designation))
print(len(company))
print(len(skills))
print(len(location))
# Out:
# 0
# 0
# 0
# 0
# 0

# %% [markdown]
# Q8.Scrape the details of Highest selling novels.
#
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/
#
# You have to find the following details:
#
# A) Book name B) Author name C) Volumes sold D) Publisher E) Genre

# %%
#intialising driver
driver=webdriver.Chrome(r"C:\Users\Home\Downloads\chromedriver_win32 (2)\chromedriver.exe")

# %%
#getting the required url
driver.get("https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare")

# %%
# creating empty lists for scraping data
book_name = []
author_name  = []
volumes_sold  = []
publisher  = []
genre  = []

# %%
#scraping book name
book = driver.find_elements_by_xpath("//tbody/tr/td[2]")
for i in book:
    book_name.append(i.text)#appending book name

#scraping author name
author = driver.find_elements_by_xpath("//tbody/tr/td[3]")
for i in author:
    author_name.append(i.text)#appending author name

#scraping volumes sold
volume = driver.find_elements_by_xpath("//tbody/tr/td[4]")
for i in volume:
    volumes_sold.append(i.text)#appending volumes of books sold

#scraping publisher 
publish = driver.find_elements_by_xpath("//tbody/tr/td[5]")
for i in publish:
    publisher.append(i.text)#appending publisher name

#scraping genre
Genre = driver.find_elements_by_xpath("//tbody/tr/td[6]")
for i in Genre:
    genre.append(i.text)#appending genre

# %%
#checking the length of each list
print(len(book_name))
print(len(author_name))
print(len(volumes_sold))
print(len(publisher))
print(len(genre))
# Out:
# 100
# 100
# 100
# 100
# 100

# %%
#creating a dataframe
df8=pd.DataFrame({'Book Name':book_name,'AUthor Name':author_name,'Volumes Sold':volumes_sold,'Publisher':publisher,'Genre':genre})

df8
# Out:
#                                             Book Name       AUthor Name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes Sold        Publisher                        Genre
# ...

# %% [markdown]
# Q9. Scrape the details most watched tv series of all time from imdb.com.
#
# Url = https://www.imdb.com/list/ls095964455/
#
# You have to find the following details:
#
# A) Name B) Year span C) Genre D) Run time E) Ratings F) Votes

# %%
#intialising driver
driver=webdriver.Chrome(r"C:\Users\Home\Downloads\chromedriver_win32 (2)\chromedriver.exe")

# %%
#getting the required url
driver.get("https://www.imdb.com/list/ls095964455/")

# %%
# creating empty lists for scraping data
name=[]
year=[]
genre=[]
runtime=[]
ratings=[]
votes=[]

# %%
#scraping name
Name=driver.find_elements_by_xpath("//h3[@class='lister-item-header']/a")
for i in Name:
    name.append(i.text)#appending movie name
    
#scraping year
Year=driver.find_elements_by_xpath("//span[@class='lister-item-year text-muted unbold']")
for i in Year:
    year.append(i.text)#appending year of release

#scraping genre
Genre=driver.find_elements_by_xpath("//p[@class='text-muted text-small']/span[5]")
for i in Genre:
    genre.append(i.text)#appending genre

#scraping runtime
rt=driver.find_elements_by_xpath("//p[@class='text-muted text-small']/span[3]")
for i in rt:
    runtime.append(i.text)#appending runtime

#scraping ratings
Rating=driver.find_elements_by_xpath("//div[@class='ipl-rating-widget']/div/span[2]")
for i in Rating:
    ratings.append(i.text)#appending ratings

#scraping votes
Votes=driver.find_elements_by_xpath("//p[4][@class='text-muted text-small']/span[2]")
for i in Votes:
    votes.append(i.text)#appending votes

# %%
#checking the length of each list
print(len(name))
print(len(year))
print(len(genre))
print(len(runtime))
print(len(ratings))
print(len(votes))
# Out:
# 100
# 100
# 100
# 100
# 100
# 100

# %%
#creating a dataframe
df9=pd.DataFrame({'Name':name,'Year':year,'Genre':genre,'Run Time':runtime,'Ratings':ratings,'Votes':votes})

df9
# Out:
#                               Name         Year                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run Time Ratings      Votes
# 0    57 min     9.2  1,895,644
# ...

# %% [markdown]
# Q10. Details of Datasets from UCI machine learning repositories.
#
# Url = https://archive.ics.uci.edu/
#
# You have to find the following details:
#
# A) Dataset name B) Data type C) Task D) Attribute type E) No of instances F) No of attribute G) Year

# %%
#intialising driver
driver=webdriver.Chrome(r"C:\Users\Home\Downloads\chromedriver_win32 (2)\chromedriver.exe")

# %%
#getting the required url
driver.get("https://archive.ics.uci.edu/ml/index.php")

# %%
time.sleep(3)

# %%
view_all=driver.find_element_by_xpath('//table[1]/tbody/tr/td[2]/span[2]/a')

# %%
a=view_all.get_attribute('href')

# %%
driver.get(a)

# %%
nam=driver.find_elements_by_xpath('//table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td/table/tbody/tr/td[2]')

# %%
Name=[]

for i in nam:
    Name.append(i.text)

# %%
dty=driver.find_elements_by_xpath('//table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]/p[@class="normal"]')

# %%
Dataty=[]
for i in dty:
    Dataty.append(i.text)

# %%
tsk=driver.find_elements_by_xpath('//table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]/p[@class="normal"]')

# %%
task=[]
for i in tsk:
    task.append(i.text)

# %%
atr=driver.find_elements_by_xpath('//table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]/p[@class="normal"]')

# %%
attr=[]
for i in atr:
    attr.append(i.text)

# %%
ni=driver.find_elements_by_xpath('//table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]/p[@class="normal"]')

# %%
N_I=[]
for i in ni:
    N_I.append(i.text)

# %%
len(N_I)
# Out:
# 588

# %%
na=driver.find_elements_by_xpath('//table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]/p[@class="normal"]')

# %%
N_A=[]
for i in na:
    N_A.append(i.text)

# %%
y=na=driver.find_elements_by_xpath('//table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]/p[@class="normal"]')

# %%
Y=[]
for i in y:
    Y.append(i.text)

# %%
#creating a dataframe
df10=pd.DataFrame({"Name":Name,"Datatype":Dataty,"Task":task,"Attribute_Type":attr,"No of instances":N_I,
                "No of attribute":N_A , "Year" : Y})

df10
# Out:
#                                  Name       Datatype                  Task  \
# 0                             Abalone  Multivariate        Classification
# 1                               Adult  Multivariate        Classification
# 2                           Annealing  Multivariate        Classification
# 3        Anonymous Microsoft Web Data                 Recommender-Systems
# 4                          Arrhythmia  Multivariate        Classification
# ..                                ...            ...                   ...
# 583  in-vehicle coupon recommendation  Multivariate        Classification
# 584               Gait Classification  Multivariate        Classification
# 585         Wikipedia Math Essentials   Time-Series            Regression
# 586         Wikipedia Math Essentials   Time-Series            Regression
# 587      Synchronous Machine Data Set  Multivariate            Regression
#
#                   Attribute_Type No of instances No of attribute   Year
# ...
